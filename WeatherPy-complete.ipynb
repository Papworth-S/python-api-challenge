# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key
# from config import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

## Locking in the random seed numberfor consistance if it works
np.random.seed(300)

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
print(cities)
# Out:
# Number of cities in the list: 619
# ['vaitupu', 'taolanaro', 'jamestown', 'avarua', 'castro', 'nedryhayliv', 'provideniya', 'isangel', 'port alfred', 'butaritari', 'taoudenni', 'hilo', 'shchelyayur', 'nioro', 'dahuk', 'mentok', 'ankang', 'punta arenas', 'mount gambier', 'camacha', 'carnarvon', 'huarmey', 'kununurra', 'north fort myers', 'mocambique', 'bluff', 'buchanan', 'atuona', 'copiapo', 'saldanha', 'albany', 'blackfoot', 'laguna', 'barentsburg', 'mataura', 'hami', 'busselton', 'tigil', 'chuy', 'killybegs', 'coihaique', 'daru', 'kytlym', 'lakheri', 'torbay', 'constantine', 'svetlyy', 'alice springs', 'los llanos de aridane', 'araouane', 'mountain home', 'ilulissat', 'tuktoyaktuk', 'khatanga', 'mugur-aksy', 'breves', 'jiddah', 'zvishavane', 'florencia', 'iqaluit', 'esperance', 'amderma', 'umba', 'vanimo', 'sao joao da barra', 'terrak', 'new norfolk', 'ejido', 'manta', 'aklavik', 'ushuaia', 'north bend', 'sao jose da coroa grande', 'okhotsk', 'sitka', 'kaitangata', 'buraydah', 'basco', 'drayton valley', 'cidreira', 'lulea', 'bandarbeyla', 'kapaa', 'saleaula', 'hithadhoo', 'chirala', 'great falls', 'port moresby', 'rikitea', 'grand river south east', 'barrow', 'russell', 'teya', 'roald', 'victoria', 'half moon bay', 'mosquera', 'tezu', 'manzhouli', 'port lincoln', 'salcea', 'vaini', 'nizhneyansk', 'ponoka', 'qaanaaq', 'bethel', 'hermanus', 'tarata', 'saint-philippe', 'thompson', 'talnakh', 'kiunga', 'tucuru', 'turukhansk', 'tateyama', 'enid', 'souillac', 'fort-shevchenko', 'severo-kurilsk', 'kolpny', 'mar del plata', 'bengkulu', 'arraial do cabo', 'guerrero negro', 'chermoz', 'dikson', 'severo-yeniseyskiy', 'kehychivka', 'orlik', 'gulu', 'lebu', 'raudeberg', 'kavaratti', 'tayu', 'adrar', 'kodiak', 'kisiwani', 'bera', 'tierralta', 'warrington', 'sola', 'georgetown', 'ribeira grande', 'olinda', 'fort saint john', 'hobart', 'wausau', 'itoman', 'bambous virieux', 'hasaki', 'paamiut', 'tual', 'kloulklubed', 'puerto ayora', 'sorong', 'kamaishi', 'novyy urengoy', 'samarai', 'port hardy', 'sentyabrskiy', 'westport', 'poum', 'nizhniy ingash', 'paragominas', 'batemans bay', 'meulaboh', 'mumford', 'palmer', 'kenitra', 'otrado-kubanskoye', 'bredasdorp', 'havoysund', 'beloha', 'yellowknife', 'vila franca do campo', 'salalah', 'prabumulih', 'masuguru', 'ciudad bolivar', 'deputatskiy', 'saint-pierre', 'upernavik', 'sainte-anne-des-monts', 'vila velha', 'itaqui', 'tangzhai', 'ambunti', 'baruun-urt', 'polovinnoye', 'port elizabeth', 'vardo', 'homer', 'potiskum', 'narsaq', 'korla', 'san cristobal', 'lakshettipet', 'makat', 'nikolskoye', 'sotuta', 'constitucion', 'kendari', 'san patricio', 'norman wells', 'ngunguru', 'attawapiskat', 'lamont', 'lima', 'sabang', 'chulman', 'sept-iles', 'nouadhibou', 'bathsheba', 'umm lajj', 'purranque', 'nalut', 'nanakuli', 'sobolevo', 'victor harbor', 'banjarmasin', 'karratha', 'sao filipe', 'preston', 'gorom-gorom', 'tasiilaq', 'harrisonville', 'leningradskiy', 'margate', 'cape town', 'the valley', 'necochea', 'katsuura', 'guadalajara', 'tarudant', 'chumikan', 'amapa', 'seoul', 'prince albert', 'the pas', 'naze', 'belushya guba', 'aguimes', 'chokurdakh', 'valparai', 'awbari', 'cockburn town', 'kedougou', 'cabo san lucas', 'east london', 'mahebourg', 'veletma', 'sulphur', 'plettenberg bay', 'oktyabrskoye', 'kirakira', 'muzhi', 'saskylakh', 'ponta do sol', 'lorengau', 'anadyr', 'padang', 'temaraia', 'te anau', 'bubaque', 'ust-bolsheretsk', 'longyearbyen', 'barranca', 'hofn', 'fayaoue', 'kosh-agach', 'envira', 'marawi', 'khonuu', 'cherskiy', 'marsabit', 'stepnogorsk', 'yeppoon', 'soe', 'cedar city', 'prince rupert', 'itarsi', 'atambua', 'pastavy', 'la rioja', 'gobabis', 'karasjok', 'bulawayo', 'vysokogornyy', 'omsukchan', 'bida', 'kodinsk', 'zlitan', 'sunrise', 'codrington', 'bar-le-duc', 'ahipara', 'riyadh', 'vsevolodo-vilva', 'saint george', 'ostrovnoy', 'acapulco', 'yerbogachen', 'tiksi', 'saint-augustin', 'hirara', 'nongpoh', 'udachnyy', 'qasigiannguit', 'tuatapere', 'taseyevo', 'aripuana', 'rio branco do sul', 'pisco', 'gewane', 'zuwarah', 'niz ...

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Testing a single call because the mass called errored out 
# for some reason it was not pulling in the key from from api_keys import weather_api_key 
# even though I had changed the text and saved the file but it works now
# units = "metric"
# base_url = "http://api.openweathermap.org/data/2.5/weather?"
# city_url = f"{base_url}appid={weather_api_key}&q={city}&units={units}"
# city_weather = requests.get(city_url)
# print(city_weather)
# Out:
# <Response [200]>

# %%
# reading the json from the pull it works just fine
# city_weather_json = city_weather.json()
# pprint(city_weather_json)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 86},
#  'cod': 200,
#  'coord': {'lat': -20.4081, 'lon': 57.7},
#  'dt': 1680491474,
#  'id': 934322,
#  'main': {'feels_like': 29.41,
#           'grnd_level': 1010,
#           'humidity': 81,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 26.81,
#           'temp_max': 26.81,
#           'temp_min': 26.81},
#  'name': 'Mahébourg',
#  'rain': {'1h': 0.22},
#  'sys': {'country': 'MU',
#          'id': 2002134,
#          'sunrise': 1680488194,
#          'sunset': 1680530902,
#          'type': 2},
#  'timezone': 14400,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 53, 'gust': 5.44, 'speed': 3.85}}

# %%
# Set the API base URL
base_url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{base_url}appid={weather_api_key}&q={city}&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url)
        city_weather_json = city_weather.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather_json["coord"]["lat"]
        city_lng = city_weather_json["coord"]["lon"]
        city_max_temp = city_weather_json["main"]["temp_max"]
        city_humidity = city_weather_json["main"]["humidity"]
        city_clouds = city_weather_json["clouds"]["all"]
        city_wind = city_weather_json["wind"]["speed"]
        city_country = city_weather_json["sys"]["country"]
        city_date = city_weather_json["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | castro
# Processing Record 6 of Set 1 | nedryhayliv
# Processing Record 7 of Set 1 | provideniya
# Processing Record 8 of Set 1 | isangel
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | taoudenni
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | shchelyayur
# City not found. Skipping...
# Processing Record 14 of Set 1 | nioro
# Processing Record 15 of Set 1 | dahuk
# Processing Record 16 of Set 1 | mentok
# City not found. Skipping...
# Processing Record 17 of Set 1 | ankang
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | mount gambier
# Processing Record 20 of Set 1 | camacha
# Processing Record 21 of Set 1 | carnarvon
# Processing Record 22 of Set 1 | huarmey
# Processing Record 23 of Set 1 | kununurra
# Processing Record 24 of Set 1 | north fort myers
# Processing Record 25 of Set 1 | mocambique
# City not found. Skipping...
# Processing Record 26 of Set 1 | bluff
# Processing Record 27 of Set 1 | buchanan
# Processing Record 28 of Set 1 | atuona
# Processing Record 29 of Set 1 | copiapo
# Processing Record 30 of Set 1 | saldanha
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | blackfoot
# Processing Record 33 of Set 1 | laguna
# Processing Record 34 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | hami
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | tigil
# Processing Record 39 of Set 1 | chuy
# Processing Record 40 of Set 1 | killybegs
# Processing Record 41 of Set 1 | coihaique
# Processing Record 42 of Set 1 | daru
# Processing Record 43 of Set 1 | kytlym
# City not found. Skipping...
# Processing Record 44 of Set 1 | lakheri
# Processing Record 45 of Set 1 | torbay
# Processing Record 46 of Set 1 | constantine
# Processing Record 47 of Set 1 | svetlyy
# Processing Record 48 of Set 1 | alice springs
# Processing Record 49 of Set 1 | los llanos de aridane
# Processing Record 50 of Set 1 | araouane
# Processing Record 0 of Set 2 | mountain home
# Processing Record 1 of Set 2 | ilulissat
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | khatanga
# Processing Record 4 of Set 2 | mugur-aksy
# Processing Record 5 of Set 2 | breves
# Processing Record 6 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 7 of Set 2 | zvishavane
# Processing Record 8 of Set 2 | florencia
# Processing Record 9 of Set 2 | iqaluit
# Processing Record 10 of Set 2 | esperance
# Processing Record 11 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 2 | umba
# Processing Record 13 of Set 2 | vanimo
# Processing Record 14 of Set 2 | sao joao da barra
# Processing Record 15 of Set 2 | terrak
# Processing Record 16 of Set 2 | new norfolk
# Processing Record 17 of Set 2 | ejido
# Processing Record 18 of Set 2 | manta
# Processing Record 19 of Set 2 | aklavik
# Processing Record 20 of Set 2 | ushuaia
# Processing Record 21 of Set 2 | north bend
# Processing Record 22 of Set 2 | sao jose da coroa grande
# Processing Record 23 of Set 2 | okhotsk
# Processing Record 24 of Set 2 | sitka
# Processing Record 25 of Set 2 | kaitangata
# Processing Record 26 of Set 2 | buraydah
# Processing Record 27 of Set 2 | basco
# Processing Record 28 of Set 2 | drayton valley
# Processing Record 29 of Set 2 | cidreira
# Processing Record 30 of Set 2 | lulea
# Processing Record 31 of Set 2 | bandarbeyla
# Processing Record 32 of Set 2 | kapaa
# Processing Record 33 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 2 | hithadhoo
# Processing Record 35 of Set 2 | chirala
# Processing Record 36 of Set 2 | great falls
# Processing Record 37 of Set 2 | port moresby
# Processing Record 38 of Set 2 | rikitea
# Processing Record 39 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 2 | barrow
# Processing Record 41 of Set 2 | russell
# Processing Record 42 of Set 2 | teya
# Processing Record 43 of Set 2 | roald
# Processing Record 44 of Set 2 | victoria
# Processing Record 45 of Set 2 | half moon bay
# Processing Record 46 of Set 2 | mosquera
# Processing Record 47 of Set 2 | tezu
# Processing Record 48 of Set 2 | manzhouli
# Processing Record 49 of Set 2 | port lincoln
# Processing Record 0 of Set 3 | salcea
# Processing Record 1 of Set 3 | vaini
# Processing Record 2 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 3 | ponoka
# Processing Record 4 of Set 3 | qaanaaq
# Processing Record 5 of Set 3 | bethel
# Processing Record 6 of Set 3 | hermanus
# Processing Record 7 of Set 3 | tarata
# Processing Record 8 of Set 3 | saint-philippe
# Processing Record 9 of Set 3 | thompson
# Processing Record 10 of Set 3 | talnakh
# Processing Record 11 of Set 3 | kiunga
# Processing Record 12 of Set 3 | tucuru
# Processing Record 13 of Set 3 | turukhansk
# Processing Record 14 of Set 3 | tateyama
# Processing Record 15 of Set 3 | enid
# Processing Record 16 of Set 3 | souillac
# Processing Record 17 of Set 3 | fort-shevchenko
# Processing Record 18 of Set 3 | severo-kurilsk
# Processing Record 19 of Set 3 | kolpny
# Processing Record 20 of Set 3 | mar del plata
# Processing Record 21 of Set 3 | bengkulu
# Processing Record 22 of Set 3 | arraial do cabo
# Processing Record 23 of Set 3 | guerrero negro
# Processing Record 24 of Set 3 | chermoz
# Processing Record 25 of Set 3 | dikson
# Processing Record 26 of Set 3 | severo-yeniseyskiy
# Processing Record 27 of Set 3 | kehychivka
# Processing Record 28 of Set 3 | orlik
# Processing Record 29 of Set 3 | gulu
# Processing Record 30 of Set 3 | lebu
# Processing Record 31 of Set 3 | raudeberg
# Processing Record 32 of Set 3 | kavaratti
# Processing Record 33 of Set 3 | tayu
# Processing Record 34 of Set 3 | adrar
# Processing Record 35 of Set 3 | kodiak
# Processing Record 36 of Set 3 | kisiwani
# Processing Record 37 of Set 3 | bera
# Processing Record 38 of Set 3 | tierralta
# Processing Record 39 of Set 3 | warrington
# Processing Record 40 of Set 3 | sola
# Processing Record 41 of Set 3 | georgetown
# Processing Record 42 of Set 3 | ribeira grande
# Processing Record 43 of Set 3 | olinda
# Processing Record 44 of Set 3 | fort saint john
# City not found. Skipping...
# Processing Record 45 of Set 3 | hobart
# Processing Record 46 of Set 3 | wausau
# Processing Record 47 of Set 3 | itoman
# Processing Record 48 of Set 3 | bambous virieux
# Processing Record 49 of Set 3 | hasaki
# Processing Record 0 of Set 4 | paamiut
# Processing Record 1 of Set 4 | tual
# Processing Record 2 of Set 4 | kloulklubed
# Processing Record 3 of Set 4 | puerto ayora
# Processing Record 4 of Set 4 | sorong
# Processing Record 5 of Set 4 | kamaishi
# Processing Record 6 of Set 4 | novyy urengoy
# Processing Record 7 of Set 4 | samarai
# Processing Record 8 of Set 4 | port hardy
# Processing Record 9 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 4 | westport
# Processing Record 11 of Set 4 | poum
# Processing Record 12 of Set 4 | nizhniy ingash
# Processing Record 13 of Set 4 | paragominas
# Processing Record 14 of Set 4 | batemans bay
# Processing Record 15 of Set 4 | meulaboh
# Processing Record 16 of Set 4 | mumford
# Processing Record 17 of Set 4 | palmer
# Processing Record 18 of Set 4 | kenitra
# Processing Record 19 of Set 4 | otrado-kubanskoye
# Processing Record 20 of Set 4 | bredasdorp
# Processing Record 21 of Set 4 | havoysund
# Processing Record 22 of Set 4 | beloha
# Processing Record 23 of Set 4 | yellowknife
# Processing Record 24 of Set 4 | vila franca do campo
# Processing Record 25 of Set 4 | salalah
# Processing Record 26 of Set 4 | prabumulih
# Processing Record 27 of Set 4 | masuguru
# Processing Record 28 of Set 4 | ciudad bolivar
# Processing Record 29 of Set 4 | deputatskiy
# Processing Record 30 of Set 4 | saint-pierre
# Processing Record 31 of Set 4 | upernavik
# Processing Record 32 of Set 4 | sainte-anne-des-monts
# Processing Record 33 of Set 4 | vila velha
# Processing Record 34 of Set 4 | itaqui
# Processing Record 35 of Set 4 | tangzhai
# Processing Record 36 of Set 4 | ambunti
# Processing Record 37 of Set 4 | baruun-urt
# Processing Record 38 of Set 4 | polovinnoye
# Processing Record 39 of Set 4 | port elizabeth
# Processing Record 40 of Set 4 | vardo
# Processing Record 41 of Set 4 | homer
# Processing Record 42 of Set 4 | potiskum
# Processing Record 43 of Set 4 | narsaq
# Processing Record 44 of Set 4 | korla
# Processing Record 45 of Set 4 | san cristobal
# Processing Record 46 of Set 4 | lakshettipet
# Processing Record 47 of Set 4 | makat
# Processing Record 48 of Set 4 | nikolskoye
# Processing Record 49 of Set 4 | sotuta
# Processing Record 0 of Set 5 | constitucion
# Processing Record 1 of Set 5 | kendari
# Processing Record 2 of Set 5 | san patricio
# Processing Record 3 of Set 5 | norman wells
# Processing Record 4 of Set 5 | ngunguru
# Processing Record 5 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 5 | lamont
# Processing Record 7 of Set 5 | lima
# Processing Record 8 of Set 5 | sabang
# Processing Record 9 of Set 5 | chulman
# Processing Record 10 of Set 5 | sept-iles
# Processing Record 11 of Set 5 | nouadhibou
# Processing Record 12 of Set 5 | bathsheba
# Processing Record 13 of Set 5 | umm lajj
# Processing Record 14 of Set 5 | purranque
# Processing Record 15 of Set 5 | nalut
# Processing Record 16 of Set 5 | nanakuli
# Processing Record 17 of Set 5 | sobolevo
# Processing Record 18 of Set 5 | victor harbor
# Processing Record 19 of Set 5 | banjarmasin
# Processing Record 20 of Set 5 | karratha
# Processing Record 21 of Set 5 | sao filipe
# Processing Record 22 of Set 5 | preston
# Processing Record 23 of Set 5 | gorom-gorom
# Processing Record 24 of Set 5 | tasiilaq
# Processing Record 25 of Set 5 | harrisonville
# Processing Record 26 of Set 5 | leningradskiy
# Processing Record 27 of Set 5 | margate
# Processing Record 28 of Set 5 | cape town
# Processing Record 29 of Set 5 | the valley
# Processing Record 30 of Set 5 | necochea
# Processing Record 31 of Set 5 | katsuura
# Processing Record 32 of Set 5 | guadalajara
# Processing Record 33 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 34 of Set 5 | chumikan
# Processing Record 35 of Set 5 | amapa
# Processing Record 36 of Set 5 | seoul
# Processing Record 37 of Set 5 | prince albert
# Processing Record 38 of Set 5 | the pas
# Processing Record 39 of Set 5 | naze
# Processing Record 40 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 5 | aguimes
# Processing Record 42 of Set 5 | chokurdakh
# Processing Record 43 of Set 5 | valparai
# Processing Record 44 of Set 5 | awbari
# Processing Record 45 of Set 5 | cockburn town
# Processing Record 46 of Set 5 | kedougou
# Processing Record 47 of Set 5 | cabo san lucas
# Processing Record 48 of Set 5 | east london
# Processing Record 49 of Set 5 | mahebourg
# Processing Record 0 of Set 6 | veletma
# City not found. Skipping...
# Processing Record 1 of Set 6 | sulphur
# Processing Record 2 of Set 6 | plettenberg bay
# Processing Record 3 of Set 6 | oktyabrskoye
# Processing Record 4 of Set 6 | kirakira
# Processing Record 5 of Set 6 | muzhi
# Processing Record 6 of Set 6 | saskylakh
# Processing Record 7 of Set 6 | ponta do sol
# Processing Record 8 of Set 6 | lorengau
# Processing Record 9 of Set 6 | anadyr
# Processing Record 10 of Set 6 | padang
# Processing Record 11 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 12 of Set 6 | te anau
# Processing Record 13 of Set 6 | bubaque
# Processing Record 14 of Set 6 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 15 of Set 6 | longyearbyen
# Processing Record 16 of Set 6 | barranca
# Processing Record 17 of Set 6 | hofn
# Processing Record 18 of Set 6 | fayaoue
# Processing Record 19 of Set 6 | kosh-agach
# Processing Record 20 of Set 6 | envira
# Processing Record 21 of Set 6 | marawi
# Processing Record 22 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 23 of Set 6 | cherskiy
# Processing Record 24 of Set 6 | marsabit
# Processing Record 25 of Set 6 | stepnogorsk
# Processing Record 26 of Set 6 | yeppoon
# Processing Record 27 of Set 6 | soe
# Processing Record 28 of Set 6 | cedar city
# Processing Record 29 of Set 6 | prince rupert
# Processing Record 30 of Set 6 | itarsi
# Processing Record 31 of Set 6 | atambua
# Processing Record 32 of Set 6 | pastavy
# Processing Record 33 of Set 6 | la rioja
# Processing Record 34 of Set 6 | gobabis
# Processing Record 35 of Set 6 | karasjok
# Processing Record 36 of Set 6 | bulawayo
# Processing Record 37 of Set 6 | vysokogornyy
# Processing Record 38 of Set 6 | omsukchan
# Processing Record 39 of Set 6 | bida
# Processing Record 40 of Set 6 | kodinsk
# Processing Record 41 of Set 6 | zlitan
# Processing Record 42 of Set 6 | sunrise
# Processing Record 43 of Set 6 | codrington
# Processing Record 44 of Set 6 | bar-le-duc
# Processing Record 45 of Set 6 | ahipara
# Processing Record 46 of Set 6 | riyadh
# Processing Record 47 of Set 6 | vsevolodo-vilva
# City not found. Skipping...
# Processing Record 48 of Set 6 | saint george
# Processing Record 49 of Set 6 | ostrovnoy
# Processing Record 0 of Set 7 | acapulco
# Processing Record 1 of Set 7 | yerbogachen
# Processing Record 2 of Set 7 | tiksi
# Processing Record 3 of Set 7 | saint-augustin
# Processing Record 4 of Set 7 | hirara
# Processing Record 5 of Set 7 | nongpoh
# Processing Record 6 of Set 7 | udachnyy
# Processing Record 7 of Set 7 | qasigiannguit
# Processing Record 8 of Set 7 | tuatapere
# Processing Record 9 of Set 7 | taseyevo
# Processing Record 10 of Set 7 | aripuana
# Processing Record 11 of Set 7 | rio branco do sul
# Processing Record 12 of Set 7 | pisco
# Processing Record 13 of Set 7 | gewane
# Processing Record 14 of Set 7 | zuwarah
# Processing Record 15 of Set 7 | nizwa
# Processing Record 16 of Set 7 | eenhana
# Processing Record 17 of Set 7 | juneau
# Processing Record 18 of Set 7 | acajutla
# Processing Record 19 of Set 7 | damietta
# Processing Record 20 of Set 7 | touros
# Processing Record 21 of Set 7 | diego de almagro
# Processing Record 22 of Set 7 | kaura namoda
# Processing Record 23 of Set 7 | goundi
# Processing Record 24 of Set 7 | hulan
# Processing Record 25 of Set 7 | lagoa
# Processing Record 26 of Set 7 | christchurch
# Processing Record 27 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 7 | luanda
# Processing Record 29 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 30 of Set 7 | geraldton
# Processing Record 31 of Set 7 | broome
# Processing Record 32 of Set 7 | hay river
# Processing Record 33 of Set 7 | kimbe
# Processing Record 34 of Set 7 | plerin
# Processing Record 35 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 7 | serebryansk
# Processing Record 37 of Set 7 | sulina
# Processing Record 38 of Set 7 | wolow
# Processing Record 39 of Set 7 | sibolga
# Processing Record 40 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 7 | husavik
# Processing Record 42 of Set 7 | moussoro
# Processing Record 43 of Set 7 | clyde river
# Processing Record 44 of Set 7 | lompoc
# Processing Record 45 of Set 7 | cap malheureux
# Processing Record 46 of Set 7 | spasskoye
# Processing Record 47 of Set 7 | puerto del rosario
# Processing Record 48 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 7 | doha
# Processing Record 0 of Set 8 | nipawin
# Processing Record 1 of Set 8 | cabedelo
# Processing Record 2 of Set 8 | toulepleu
# City not found. Skipping...
# Processing Record 3 of Set 8 | tikrit
# Processing Record 4 of Set 8 | zhuozhou
# City not found. Skipping...
# Processing Record 5 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 6 of Set 8 | airai
# Processing Record 7 of Set 8 | zharkent
# Processing Record 8 of Set 8 | birin
# Processing Record 9 of Set 8 | saint paul
# Processing Record 10 of Set 8 | arvika
# Processing Record 11 of Set 8 | mus
# Processing Record 12 of Set 8 | rodrigues alves
# Processing Record 13 of Set 8 | tautira
# Processing Record 14 of Set 8 | tura
# Processing Record 15 of Set 8 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 8 | perbaungan
# Processing Record 17 of Set 8 | amahai
# Processing Record 18 of Set 8 | itarema
# Processing Record 19 of Set 8 | jiran
# Processing Record 20 of Set 8 | brooks
# Processing Record 21 of Set 8 | lavrentiya
# Processing Record 22 of Set 8 | tari
# Processing Record 23 of Set 8 | gurabo
# Processing Record 24 of Set 8 | taranagar
# Processing Record 25 of Set 8 | yar-sale
# Processing Record 26 of Set 8 | boende
# Processing Record 27 of Set 8 | jinchang
# Processing Record 28 of Set 8 | ambon
# Processing Record 29 of Set 8 | milot
# Processing Record 30 of Set 8 | bell ville
# Processing Record 31 of Set 8 | haines junction
# Processing Record 32 of Set 8 | bilma
# Processing Record 33 of Set 8 | talcahuano
# Processing Record 34 of Set 8 | da nang
# Processing Record 35 of Set 8 | ugoofaaru
# Processing Record 36 of Set 8 | riviere-au-renard
# Processing Record 37 of Set 8 | digboi
# Processing Record 38 of Set 8 | heidelberg
# Processing Record 39 of Set 8 | naron
# Processing Record 40 of Set 8 | pevek
# Processing Record 41 of Set 8 | miraflores
# Processing Record 42 of Set 8 | storsteinnes
# Processing Record 43 of Set 8 | freeport
# Processing Record 44 of Set 8 | asau
# Processing Record 45 of Set 8 | angoram
# Processing Record 46 of Set 8 | kamenka
# Processing Record 47 of Set 8 | klaksvik
# Processing Record 48 of Set 8 | banmo
# City not found. Skipping...
# Processing Record 49 of Set 8 | mahajanga
# Processing Record 0 of Set 9 | ouesso
# Processing Record 1 of Set 9 | ishigaki
# Processing Record 2 of Set 9 | kolokani
# Processing Record 3 of Set 9 | ekibastuz
# Processing Record 4 of Set 9 | kangaatsiaq
# Processing Record 5 of Set 9 | anar darreh
# City not found. Skipping...
# Processing Record 6 of Set 9 | armacao dos buzios
# City not found. Skipping...
# Processing Record 7 of Set 9 | ust-tsilma
# Processing Record 8 of Set 9 | oranjemund
# Processing Record 9 of Set 9 | cape coast
# Processing Record 10 of Set 9 | banda aceh
# Processing Record 11 of Set 9 | beringovskiy
# Processing Record 12 of Set 9 | skalat
# Processing Record 13 of Set 9 | lander
# Processing Record 14 of Set 9 | komsomolskiy
# Processing Record 15 of Set 9 | antofagasta
# Processing Record 16 of Set 9 | luderitz
# Processing Record 17 of Set 9 | kassala
# Processing Record 18 of Set 9 | leeton
# Processing Record 19 of Set 9 | bosaso
# Processing Record 20 of Set 9 | san quintin
# Processing Record 21 of Set 9 | chernyshevskiy
# Processing Record 22 of Set 9 | kristiinankaupunki
# Processing Record 23 of Set 9 | namatanai
# Processing Record 24 of Set 9 | bani walid
# Processing Record 25 of Set 9 | coquimbo
# Processing Record 26 of Set 9 | enterprise
# Processing Record 27 of Set 9 | kinablangan
# Processing Record 28 of Set 9 | portland
# Processing Record 29 of Set 9 | poco verde
# Processing Record 30 of Set 9 | xuddur
# Processing Record 31 of Set 9 | borogontsy
# Processing Record 32 of Set 9 | tessalit
# Processing Record 33 of Set 9 | rapid valley
# Processing Record 34 of Set 9 | tucuman
# Processing Record 35 of Set 9 | rucheng
# Processing Record 36 of Set 9 | moa
# Processing Record 37 of Set 9 | alihe
# Processing Record 38 of Set 9 | dunnville
# Processing Record 39 of Set 9 | andros
# Processing Record 40 of Set 9 | aviles
# Processing Record 41 of Set 9 | mamakan
# Processing Record 42 of Set 9 | jalu
# Processing Record 43 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 9 | beisfjord
# Processing Record 45 of Set 9 | baykit
# Processing Record 46 of Set 9 | vao
# Processing Record 47 of Set 9 | ajdabiya
# Processing Record 48 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 9 | turkan
# Processing Record 0 of Set 10 | aromashevo
# Processing Record 1 of Set 10 | gaoua
# Processing Record 2 of Set 10 | nova olimpia
# Processing Record 3 of Set 10 | bereda
# Processing Record 4 of Set 10 | leh
# Processing Record 5 of Set 10 | gigmoto
# Processing Record 6 of Set 10 | hovd
# Processing Record 7 of Set 10 | soyo
# Processing Record 8 of Set 10 | bima
# Processing Record 9 of Set 10 | baltay
# Processing Record 10 of Set 10 | manicore
# Processing Record 11 of Set 10 | katobu
# Processing Record 12 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 13 of Set 10 | svetlaya
# Processing Record 14 of Set 10 | salinopolis
# Processing Record 15 of Set 10 | murmashi
# Processing Record 16 of Set 10 | ihosy
# Processing Record 17 of Set 10 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 18 of Set 10 | coxim
# Processing Record 19 of Set 10 | marystown
# Processing Record 20 of Set 10 | inhambane
# Processing Record 21 of Set 10 | marsh harbour
# Processing Record 22 of Set 10 | santa cruz
# Processing Record 23 of Set 10 | henties bay
# Processing Record 24 of Set 10 | villazon
# Processing Record 25 of Set 10 | martapura
# Processing Record 26 of Set 10 | thinadhoo
# Processing Record 27 of Set 10 | kurchum
# Processing Record 28 of Set 10 | gorontalo
# Processing Record 29 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 10 | boralday
# Processing Record 31 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 32 of Set 10 | yaring
# Processing Record 33 of Set 10 | teguise
# Processing Record 34 of Set 10 | oum hadjer
# Processing Record 35 of Set 10 | kashan
# Processing Record 36 of Set 10 | sri aman
# Processing Record 37 of Set 10 | kudahuvadhoo
# Processing Record 38 of Set 10 | oistins
# Processing Record 39 of Set 10 | ilheus
# Processing Record 40 of Set 10 | kahului
# Processing Record 41 of Set 10 | karaton
# Processing Record 42 of Set 10 | shubarshi
# Processing Record 43 of Set 10 | el badari
# City not found. Skipping...
# Processing Record 44 of Set 10 | fuengirola
# Processing Record 45 of Set 10 | foam lake
# Processing Record 46 of Set 10 | zhigansk
# Processing Record 47 of Set 10 | porto velho
# Processing Record 48 of Set 10 | pitimbu
# Processing Record 49 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 0 of Set 11 | mariakani
# Processing Record 1 of Set 11 | balmedie
# Processing Record 2 of Set 11 | oksfjord
# Processing Record 3 of Set 11 | shimoda
# Processing Record 4 of Set 11 | allapalli
# Processing Record 5 of Set 11 | nha trang
# Processing Record 6 of Set 11 | romanesti
# City not found. Skipping...
# Processing Record 7 of Set 11 | pachino
# Processing Record 8 of Set 11 | port-gentil
# Processing Record 9 of Set 11 | muros
# Processing Record 10 of Set 11 | beawar
# Processing Record 11 of Set 11 | lakes entrance
# Processing Record 12 of Set 11 | mozarlandia
# Processing Record 13 of Set 11 | lahaina
# Processing Record 14 of Set 11 | malpe
# Processing Record 15 of Set 11 | walvis bay
# Processing Record 16 of Set 11 | kokopo
# Processing Record 17 of Set 11 | sosnovo-ozerskoye
# Processing Record 18 of Set 11 | dong hoi
# Processing Record 19 of Set 11 | kruisfontein
# Processing Record 20 of Set 11 | nantucket
# Processing Record 21 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 11 | arlit
# Processing Record 23 of Set 11 | verkhoyansk
# Processing Record 24 of Set 11 | pacific grove
# Processing Record 25 of Set 11 | moron
# Processing Record 26 of Set 11 | correntina
# Processing Record 27 of Set 11 | krasnyy yar
# Processing Record 28 of Set 11 | asosa
# Processing Record 29 of Set 11 | bud
# Processing Record 30 of Set 11 | maldonado
# Processing Record 31 of Set 11 | mandurah
# Processing Record 32 of Set 11 | umea
# Processing Record 33 of Set 11 | whitehorse
# Processing Record 34 of Set 11 | mildura
# Processing Record 35 of Set 11 | dubrovytsya
# Processing Record 36 of Set 11 | sinnamary
# Processing Record 37 of Set 11 | karabuk
# Processing Record 38 of Set 11 | sistranda
# Processing Record 39 of Set 11 | golkoy
# Processing Record 40 of Set 11 | havre-saint-pierre
# Processing Record 41 of Set 11 | ondjiva
# Processing Record 42 of Set 11 | kulhudhuffushi
# Processing Record 43 of Set 11 | ryabovo
# Processing Record 44 of Set 11 | gisborne
# Processing Record 45 of Set 11 | sovetskiy
# Processing Record 46 of Set 11 | mehamn
# Processing Record 47 of Set 11 | rapid city
# Processing Record 48 of Set 11 | ziduri
# Processing Record 49 of Set 11 | riberalta
# Processing Record 0 of Set 12 | bani
# Processing Record 1 of Set 12 | litoral del san juan
# City not found. Skipping...
# Processing Record 2 of Set 12 | rundu
# Processing Record 3 of Set 12 | januaria
# Processing Record 4 of Set 12 | hoopstad
# Processing Record 5 of Set 12 | makakilo city
# Processing Record 6 of Set 12 | mnogovershinnyy
# Processing Record 7 of Set 12 | tiznit
# Processing Record 8 of Set 12 | berdigestyakh
# Processing Record 9 of Set 12 | bairiki
# Processing Record 10 of Set 12 | zhuhai
# Processing Record 11 of Set 12 | porangatu
# Processing Record 12 of Set 12 | linares
# Processing Record 13 of Set 12 | kargasok
# Processing Record 14 of Set 12 | krasnyy chikoy
# Processing Record 15 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 12 | fuerte olimpo
# Processing Record 17 of Set 12 | churapcha
# Processing Record 18 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 19 of Set 12 | bayan
# Processing Record 20 of Set 12 | miri
# Processing Record 21 of Set 12 | bajitpur
# Processing Record 22 of Set 12 | kavieng
# Processing Record 23 of Set 12 | ilebo
# Processing Record 24 of Set 12 | ribas do rio pardo
# Processing Record 25 of Set 12 | taunton
# Processing Record 26 of Set 12 | hambantota
# Processing Record 27 of Set 12 | srednekolymsk
# Processing Record 28 of Set 12 | parkes
# Processing Record 29 of Set 12 | brae
# Processing Record 30 of Set 12 | balykshi
# Processing Record 31 of Set 12 | wenling
# Processing Record 32 of Set 12 | pacifica
# Processing Record 33 of Set 12 | takanabe
# Processing Record 34 of Set 12 | ulaangom
# Processing Record 35 of Set 12 | port augusta
# Processing Record 36 of Set 12 | faanui
# Processing Record 37 of Set 12 | kuminskiy
# Processing Record 38 of Set 12 | burgos
# Processing Record 39 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 40 of Set 12 | pocone
# Processing Record 41 of Set 12 | shabqadar
# Processing Record 42 of Set 12 | road town
# Processing Record 43 of Set 12 | fortuna
# Processing Record 44 of Set 12 | ternate
# Processing Record 45 of Set 12 | sandwick
# Processing Record 46 of Set 12 | ostersund
# Processing Record 47 of Set 12 | sioux lookout
# Processing Record 48 of Set 12 | alenquer
# Processing Record 49 of Set 12 | villa bruzual
# Processing Record 0 of Set 13 | arequipa
# Processing Record 1 of Set 13 | yaan
# Processing Record 2 of Set 13 | menomonie
# Processing Record 3 of Set 13 | boromo
# Processing Record 4 of Set 13 | nome
# Processing Record 5 of Set 13 | mporokoso
# Processing Record 6 of Set 13 | belaya gora
# Processing Record 7 of Set 13 | iskateley
# Processing Record 8 of Set 13 | suntar
# Processing Record 9 of Set 13 | kyra
# Processing Record 10 of Set 13 | petrolina de goias
# Processing Record 11 of Set 13 | mogadishu
# Processing Record 12 of Set 13 | solnechnyy
# Processing Record 13 of Set 13 | kulunda
# Processing Record 14 of Set 13 | hualmay
# Processing Record 15 of Set 13 | saint-joseph
# Processing Record 16 of Set 13 | puerto baquerizo moreno
# Processing Record 17 of Set 13 | sterling
# Processing Record 18 of Set 13 | laurel
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          571
# Lat           571
# Lng           571
# Max Temp      571
# Humidity      571
# Cloudiness    571
# Wind Speed    571
# Country       571
# Date          571
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    jamestown  42.0970  -79.2353      1.80        53         100        2.57
# 1       avarua -21.2078 -159.7750     27.03        69          75        3.60
# 2       castro -24.7911  -50.0119     13.37        99           9        2.90
# 3  nedryhayliv  50.8340   33.8763      6.76        88         100        6.02
# 4  provideniya  64.3833 -173.3000    -10.91        67          75        4.02
#
#   Country        Date
# 0      US  1680491401
# 1      CK  1680491491
# 2      BR  1680491491
# 3      UA  1680491491
# 4      RU  1680491492

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
print(city_data_df.dtypes)
city_data_df.head()
# Out:
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Country        object
# Date            int64
# dtype: object
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          jamestown  42.0970  -79.2353      1.80        53         100
# 1             avarua -21.2078 -159.7750     27.03        69          75
# 2             castro -24.7911  -50.0119     13.37        99           9
# 3        nedryhayliv  50.8340   33.8763      6.76        88         100
# 4        provideniya  64.3833 -173.3000    -10.91        67          75
#
#          Wind Speed Country        Date
# City_ID
# 0              2.57      US  1680491401
# 1              3.60      CK  1680491491
# 2              2.90      BR  1680491491
# 3              6.02      UA  1680491491
# 4              4.02      RU  1680491492

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df["Lat"]    #.astype("float")
y_values = city_data_df["Max Temp"]    #.astype("float")

plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.title('City Lattitude vs. Max Temprature (2023-04-03)')
plt.xlabel('Lattitude')
plt.ylabel('Max Temperature (°C)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df["Lat"]    #.astype("float")
y_values = city_data_df["Humidity"]    #.astype("float")

plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.title('City Lattitude vs. Humidity (2023-04-03)')
plt.xlabel('Lattitude')
plt.ylabel('Humidity (%)')
plt.grid()


# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df["Lat"]    #.astype("float")
y_values = city_data_df["Cloudiness"]    #.astype("float")

plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.title('City Lattitude vs. Cloudiness (2023-04-03)')
plt.xlabel('Lattitude')
plt.ylabel('Cloudiness (%)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df["Lat"]    #.astype("float")
y_values = city_data_df["Wind Speed"]    #.astype("float")

plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.title('City Lattitude vs. Wind Speed (2023-04-03)')
plt.xlabel('Lattitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
## I have no idea if this is correct 
def linear_regres(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values,y_values)
    
    plt.plot(x_values,regress_values,"r-")
#     plt.annotate(line_eq,(0,5),fontsize=15,color="red")
    plt.title(line_eq,fontsize=12,color="red")
    print(f"R squared: {rvalue**2}")
    plt.plot()  #do I need to return in front

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          jamestown  42.0970  -79.2353      1.80        53         100
# 3        nedryhayliv  50.8340   33.8763      6.76        88         100
# 4        provideniya  64.3833 -173.3000    -10.91        67          75
# 7         butaritari   3.0707  172.7902     27.88        75         100
# 8          taoudenni  22.6783   -3.9836     26.73         7           0
#
#          Wind Speed Country        Date
# City_ID
# 0              2.57      US  1680491401
# 3              6.02      UA  1680491491
# 4              4.02      RU  1680491492
# 7              5.26      KI  1680491494
# 8              3.60      ML  1680491494

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1              avarua -21.2078 -159.7750     27.03        69          75
# 2              castro -24.7911  -50.0119     13.37        99           9
# 5             isangel -19.5500  169.2667     29.79        70          15
# 6         port alfred -33.5906   26.8910     22.77        71         100
# 13       punta arenas -53.1500  -70.9167      9.06        66          75
#
#          Wind Speed Country        Date
# City_ID
# 1              3.60      CK  1680491491
# 2              2.90      BR  1680491491
# 5              1.68      VU  1680491492
# 6              3.75      ZA  1680491493
# 13             5.14      CL  1680491496

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"].astype("float")
y_values = northern_hemi_df["Max Temp"].astype("float")
linear_regres(x_values,y_values)

plt.xlabel('Lattitude')
plt.ylabel('Max Temp')
plt.plot()
# Out:
# R squared: 0.8223848083695564
# []

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"].astype("float")
y_values = southern_hemi_df["Max Temp"].astype("float")
linear_regres(x_values,y_values)

plt.xlabel('Lattitude')
plt.ylabel('Max Temp')
plt.plot()
# Out:
# R squared: 0.4397959500050167
# []

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Looking at the two carts the first thing we need to mention is the first chart with the positive Latitudes the numbers are descending indicating negative regression and the chart with the negative Latitudes looks like positive regression.  This will apply to all the following charts.
#
# They both have an absolute decrease in temperature the farther away from zero Latitude which is the Earths equator and should be the warmest with the constant and consistent sun rays.
#
# That is exactly what these charts are showing and the rsquared is telling us that in general this is a true statement.  The farther away from Latitude 0 the cooler it will most likely be.   However, this is more likely in the norther hemisphere than in the southern hemisphere.  The reason would have to be investigated.
#
# Of Note:  It appears we have more datapoint with almost 2.5x more north hemisphere to sourther hemispher datapoints) in the norther hemisphere which makes a lot of sense with most of the livable land is north of the equator. With a quick google search we can see why:
#
# >“Northern Hemisphere population is 6.96 billion people (**87.0% of the earth's total human population**). Southern Hemisphere population is 1.04 billion people (**13% of the population**)”.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"].astype("float")
y_values = northern_hemi_df["Humidity"].astype("float")
linear_regres(x_values,y_values)

plt.xlabel('Lattitude')
plt.ylabel('Humidity')
plt.plot()
# Out:
# R squared: 0.09532861951135746
# []

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"].astype("float")
y_values = southern_hemi_df["Humidity"].astype("float")
linear_regres(x_values,y_values)

plt.xlabel('Lattitude')
plt.ylabel('Humidity')
plt.plot()
# Out:
# R squared: 0.19155839659025095
# []

# %% [markdown]
# **Discussion about the linear relationship:**
#
# With respect to humidity and how far north or south the reading was taken is a little less unclear.  We can see regression as the data does tend for follow a bit of a slop in that it is more humid the closer to the equator.  That said there is a lot more variance and the rsquard is pretty low meaning that based off of this data we can not really predict a humidity based off a given latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"].astype("float")
y_values = northern_hemi_df["Cloudiness"].astype("float")
linear_regres(x_values,y_values)

plt.xlabel('Lattitude')
plt.ylabel('Cloudiness')
plt.plot()
# Out:
# R squared: 0.05570490852098065
# []

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"].astype("float")
y_values = southern_hemi_df["Cloudiness"].astype("float")
linear_regres(x_values,y_values)

plt.xlabel('Lattitude')
plt.ylabel('Cloudiness')
plt.plot()
# Out:
# R squared: 0.08738086883116805
# []

# %% [markdown]
# **Discussion about the linear relationship:**
#
# With respect to cloudiness at different latitudes. It is just as hard to see a decent rsquared.  The number is quit small but we do see a general liner line moving, but this time we see that in the NH (northern hemisphere) the line climbs (getting more cloudy) as we moved away from the equator but in the SH (southern hemisphere) it looks like cloudiness gets less as we move from the equator.  So this one is a bit different than the other relationships

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"].astype("float")
y_values = northern_hemi_df["Wind Speed"].astype("float")
linear_regres(x_values,y_values)

plt.xlabel('Lattitude')
plt.ylabel('Wind Speed')
plt.plot()
# Out:
# R squared: 0.017103556181949697
# []

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"].astype("float")
y_values = southern_hemi_df["Wind Speed"].astype("float")
linear_regres(x_values,y_values)

plt.xlabel('Lattitude')
plt.ylabel('Wind Speed')
plt.plot()
# Out:
# R squared: 0.06382189833662637
# []

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Lastly we have and both of these charts have the flattest regression line with pretty low rsquared values.  This tells us it is less likely latitude has much to do with wind intensity.  There is a small but again flat correlation to a slightly higher wind the further away from 0 lat.
